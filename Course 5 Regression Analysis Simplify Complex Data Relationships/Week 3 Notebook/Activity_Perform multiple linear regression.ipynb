# %% [markdown]
# # Activity: Perform multiple linear regression

# %% [markdown]
# ## Introduction

# %% [markdown]
# As you have learned, multiple linear regression helps you estimate the linear relationship between one continuous dependent variable and two or more independent variables. For data science professionals, this is a useful skill because it allows you to compare more than one variable to the variable you're measuring against. This provides the opportunity for much more thorough and flexible analysis.
#
# For this activity, you will be analyzing a small business' historical marketing promotion data. Each row corresponds to an independent marketing promotion where their business uses TV, social media, radio, and influencer promotions to increase sales. They previously had you work on finding a single variable that predicts sales, and now they are hoping to expand this analysis to include other variables that can help them target their marketing efforts.
#
# To address the business' request, you will conduct a multiple linear regression analysis to estimate sales from a combination of independent variables. This will include:
#
# * Exploring and cleaning data
# * Using plots and descriptive statistics to select the independent variables
# * Creating a fitting multiple linear regression model
# * Checking model assumptions
# * Interpreting model outputs and communicating the results to non-technical stakeholders

# %% [markdown]
# ## Step 1: Imports

# %% [markdown]
# ### Import packages

# %% [markdown]
# Import relevant Python libraries and modules.

# %%
# Import libraries and modules.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="white")
import statsmodels.api as sm
from statsmodels.formula.api import ols
import scipy.stats as stats

# %% [markdown]
# ### Load dataset

# %% [markdown]
# `Pandas` was used to load the dataset `marketing_sales_data.csv` as `data`, now display the first five rows. The variables in the dataset have been adjusted to suit the objectives of this lab. As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA.

### YOUR CODE HERE ### 
data = pd.read_csv('marketing_sales_data.csv')

# Display the first five rows.

data.head()
# Out:
#        TV      Radio  Social Media Influencer       Sales
# 0     Low   3.518070      2.293790      Micro   55.261284
# 1     Low   7.756876      2.572287       Mega   67.574904
# 2    High  20.348988      1.227180      Micro  272.250108
# 3  Medium  20.108487      2.728374       Mega  195.102176
# 4    High  31.653200      7.776978       Nano  273.960377

# %% [markdown]
# ## Step 2: Data exploration

# %% [markdown]
# ### Familiarize yourself with the data's features
#
# Start with an exploratory data analysis to familiarize yourself with the data and prepare it for modeling.
#
# The features in the data are:
#
# * TV promotional budget (in "Low," "Medium," and "High" categories)
# * Social media promotional budget (in millions of dollars)
# * Radio promotional budget (in millions of dollars)
# * Sales (in millions of dollars)
# * Influencer size (in "Mega," "Macro," "Nano," and "Micro" categories)

# %% [markdown]
# **Question:** What are some purposes of EDA before constructing a multiple linear regression model?

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# ### Create a pairplot of the data
#
# Create a pairplot to visualize the relationship between the continous variables in `data`.

# %%
# Create a pairplot of the data.

sns.pairplot(data);

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to [the content where creating a pairplot is demonstrated](https://www.coursera.org/learn/regression-analysis-simplify-complex-data-relationships/item/dnjWm).
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the function in the `seaborn` library that allows you to create a pairplot showing the relationships between variables in the data.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `pairplot()` function from the `seaborn` library and pass in the entire DataFrame.
#
# </details>

# %% [markdown]
# **Question:** Which variables have a linear relationship with `Sales`? Why are some variables in the data excluded from the preceding plot?

# %% [markdown]
# - `Radio` and `Social Media` both seem to have linear relationships with `Sales` variable so we can choose these two variables as independent variable
#
# - `TV` and `Influencer` are excluded from the pairplot because their data type are categorical.

# %% [markdown]
# ### Calculate the mean sales for each categorical variable

# %% [markdown]
# There are two categorical variables: `TV` and `Influencer`. To characterize the relationship between the categorical variables and `Sales`, find the mean `Sales` for each category in `TV` and the mean `Sales` for each category in `Influencer`.

# %%
# Calculate the mean sales for each TV category. 

data.groupby('TV')[['Sales']].mean()
# Out:
#              Sales
# TV
# High    300.853195
# Low      90.984101
# Medium  195.358032

# %%
# Calculate the mean sales for each Influencer category. 

data.groupby('Influencer')[['Sales']].mean()
# Out:
#                  Sales
# Influencer
# Macro       181.670070
# Mega        194.487941
# Micro       188.321846
# Nano        191.874432

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Find the mean `Sales` when the `TV` promotion is `High`, `Medium`, or `Low`.
#
# Find the mean `Sales` when the `Influencer` promotion is `Macro`, `Mega`, `Micro`, or `Nano`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the `groupby` operation in `pandas` to split an object (e.g., data) into groups and apply a calculation to each group.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# To calculate the mean `Sales` for each `TV` category, group by `TV`, select the `Sales` column, and then calculate the mean.
#
# Apply the same process to calculate the mean `Sales` for each `Influencer` category.
#
# </details>

# %% [markdown]
# **Question:** What do you notice about the categorical variables? Could they be useful predictors of `Sales`?

# %% [markdown]
# - `TV` can be the useful predictor for `Sales` because there's a big difference between different in mean Sales among category in `TV` variable. A large variation in Sales across TV categories suggests that this variable might have a strong influence on Sales. Given the substantial variation, it is reasonable to consider including the TV variable in the regression model as it seems to be a significant predictor of Sales.
#
# - The `Influencer` variable might not be as strong of a predictor for Sales based solely on the observed differences in mean Sales among categories. Additional analysis, such as examining the overall relationship between the `Influencer` variable and Sales, should be conducted to determine its predictive power.

# %% [markdown]
# ### Remove missing data
#
# This dataset contains rows with missing values. To correct this, drop all rows that contain missing data.

# %%
# Drop rows that contain missing data and update the DataFrame.

data = data.dropna(axis=0)
# Out:
#          TV      Radio  Social Media Influencer       Sales
# 0       Low   3.518070      2.293790      Micro   55.261284
# 1       Low   7.756876      2.572287       Mega   67.574904
# 2      High  20.348988      1.227180      Micro  272.250108
# 3    Medium  20.108487      2.728374       Mega  195.102176
# 4      High  31.653200      7.776978       Nano  273.960377
# ..      ...        ...           ...        ...         ...
# 567  Medium  14.656633      3.817980      Micro  191.521266
# 568    High  28.110171      7.358169       Mega  297.626731
# 569  Medium  11.401084      5.818697       Nano  145.416851
# 570  Medium  21.119991      5.703028      Macro  209.326830
# 571     Low  13.221237      3.660566      Micro  135.773151
#
# [572 rows x 5 columns]

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Use the `pandas` function that removes missing values.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# The `dropna()` function removes missing values from an object (e.g., DataFrame).
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use `data.dropna(axis=0)` to drop all rows with missing values in `data`. Be sure to properly update the DataFrame.
#
# </details>

# %% [markdown]
# ### Clean column names

# %% [markdown]
# The `ols()` function doesn't run when variable names contain a space. Check that the column names in `data` do not contain spaces and fix them, if needed.

# %%
# Rename all columns in data that contain a space. 

data = data.rename(columns={'Social Media':'Social_Media'})
data.head()
# Out:
#        TV      Radio  Social_Media Influencer       Sales
# 0     Low   3.518070      2.293790      Micro   55.261284
# 1     Low   7.756876      2.572287       Mega   67.574904
# 2    High  20.348988      1.227180      Micro  272.250108
# 3  Medium  20.108487      2.728374       Mega  195.102176
# 4    High  31.653200      7.776978       Nano  273.960377

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# There is one column name that contains a space. Search for it in `data`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# The `Social Media` column name in `data` contains a space. This is not allowed in the `ols()` function.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `rename()` function in `pandas` and use the `columns` argument to provide a new name for `Social Media`.
#
# </details>

# %% [markdown]
# ## Step 3: Model building

# %% [markdown]
# ### Fit a multiple linear regression model that predicts sales
#
# Using the independent variables of your choice, fit a multiple linear regression model that predicts `Sales` using two or more independent variables from `data`.

# %%
# Define the OLS formula.

ols_formula = 'Sales ~ C(TV) + Radio'


# Create an OLS model.

OLS = ols(formula = ols_formula, data=data)


# Fit the model.

model = OLS.fit()


# Save the results summary.

model_results = model.summary()


# Display the model results.

model_results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     1783.
# Date:                Sun, 23 Jul 2023   Prob (F-statistic):          1.63e-288
# Time:                        07:43:53   Log-Likelihood:                -2714.0
# No. Observations:                 572   AIC:                             5436.
# Df Residuals:                     568   BIC:                             5453.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         218.5261      6.261     34.902      0.000     206.228     230.824
# C(TV)[T.Low]     -154.2971      4.929    -31.303      0.000    -163.979    -144.616
# C(TV)[T.Medium]   -75.3120      3.624    -20.780      0.000     -82.431     -68.193
# Radio               2.9669      0.212     14.015      0.000       2.551       3.383
# ==============================================================================
# Omnibus:                       61.244   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.077
# Skew:                           0.046   Prob(JB):                     0.000119
# Kurtosis:                       2.134   Cond. No.                         142.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the content that discusses [model building](https://www.coursera.org/learn/regression-analysis-simplify-complex-data-relationships/lecture/zd74V/interpret-multiple-regression-coefficients) for linear regression.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the `ols()` function imported earlier—which creates a model from a formula and DataFrame—to create an OLS model.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# You previously learned how to specify in `ols()` that a feature is categorical.
#
# Be sure the string names for the independent variables match the column names in `data` exactly.
#
# </details>

# %% [markdown]
# **Question:** Which independent variables did you choose for the model, and why?

# %% [markdown]
# - I choose `Radio` and `TV` as independent for the model because `Radio` has strong linear relationship with the `Sales` dependent variable and `TV` also has large variation among category in mean Sales. So these features suggest that both variables have the potential to be strong predictors of `Sales`.

# %% [markdown]
# ### Check model assumptions

# %% [markdown]
# For multiple linear regression, there is an additional assumption added to the four simple linear regression assumptions: **multicollinearity**.
#
# Check that all five multiple linear regression assumptions are upheld for your model.

# %% [markdown]
# ### Model assumption: Linearity

# %% [markdown]
# Create scatterplots comparing the continuous independent variable(s) you selected previously with `Sales` to check the linearity assumption. Use the pairplot you created earlier to verify the linearity assumption or create new scatterplots comparing the variables of interest.

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Scatter plot - Relationship between Radio and Sales
sns.scatterplot(x=data['Radio'], y=data['Sales'], ax=axes[0, 0]).set(title='Relationship between Radio and Sales')

# Bar plot - Relationship between TV and Sales
sns.barplot(x=data['TV'], y=data['Sales'], ax=axes[0, 1], order=['Low', 'Medium', 'High']).set(title='Relationship between TV and Sales')

# Scatter plot - Relationship between Social_Media and Sales
sns.scatterplot(x=data['Social_Media'], y=data['Sales'], ax=axes[1, 0]).set(title='Relationship between Social_Media and Sales')

# Bar plot - Relationship between Influencer and Sales
sns.barplot(x=data['Influencer'], y=data['Sales'], ax=axes[1, 1], order=['Micro', 'Nano', 'Macro','Mega']).set(title='Relationship between Influencer and Sales')

# Adjust the layout to avoid overlapping titles and labels
plt.tight_layout()

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Use the function in the `seaborn` library that allows you to create a scatterplot to display the values for two variables.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the `scatterplot()` function in `seaborn`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Pass the independent and dependent variables in your model as the arguments for `x` and `y`, respectively, in the `scatterplot()` function. Do this for each continous independent variable in your model.
#
# </details>

# %% [markdown]
# **Question:** Is the linearity assumption met?

# %% [markdown]
# - There is a clear linear relationship in the scatterplot between `Radio` and `Sales`, suggesting that the linear assumption is met for the `Radio` variable.
# - `Social Media` was not included in the preceding multiple linear regression model due to its weak relationship with `Sales`.
# - Although we cannot directly check the linear relationship of a categorical variable, we can still infer its impact on 'Sales' from the bar plots. The significant differences in the heights of the `TV` bars suggest that the `TV` variable has an impact on the `Sales` variable. On the other hand, the lack of significant differences in the heights of the `Influencer` bars indicates that the `Influencer` variable likely has little impact on the `Sales` variable.

# %% [markdown]
# ### Model assumption: Independence

# %% [markdown]
# The **independent observation assumption** states that each observation in the dataset is independent. As each marketing promotion (i.e., row) is independent from one another, the independence assumption is not violated.

# %% [markdown]
# ### Model assumption: Normality

# %% [markdown]
# Create the following plots to check the **normality assumption**:
#
# * **Plot 1**: Histogram of the residuals
# * **Plot 2**: Q-Q plot of the residuals

# %%
# Calculate the residuals from the regression model
residuals = model.resid

# Create a 1x2 grid of subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Plot 1: Histogram of Residuals
sns.histplot(residuals, ax=axes[0])
axes[0].set_title('Histogram of Residuals')
axes[0].set_xlabel('Residuals')

# Plot 2: Q-Q Plot of Residuals
sm.qqplot(residuals, line='s', ax=axes[1])
axes[1].set_title('Q-Q Plot of Residuals')

# Show the plots
plt.tight_layout()

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Access the residuals from the fit model object.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use `model.resid` to get the residuals from a fit model called `model`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# For the histogram, pass the residuals as the first argument in the `seaborn` `histplot()` function.
#
# For the Q-Q plot, pass the residuals as the first argument in the `statsmodels` `qqplot()` function.
#
# </details>

# %% [markdown]
# **Question:** Is the normality assumption met?

# %% [markdown]
# - The histogram of the residuals are approximately normally distributed, which supports that the normality assumption is met for this model.
#
# - We can see the residuals in the Q-Q plot form approximately a straight line, furthur supporting that this assumption is met.

# %% [markdown]
# ### Model assumption: Constant variance

# %% [markdown]
# Check that the **constant variance assumption** is not violated by creating a scatterplot with the fitted values and residuals. Add a line at $y = 0$ to visualize the variance of residuals above and below $y = 0$.

# %%
fitted_values = model.fittedvalues

# Create a scatterplot with the fitted values from the model and the residuals.

sns.scatterplot(x=fitted_values, y=residuals)

# Add label and title
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.title("Fitted Values v. Residuals")

# Add a line at y = 0 to visualize the variance of residuals above and below 0.

plt.axhline(0, color='r');

# %% [markdown]
# Similar using `sns.residplot`

# %%
# Assuming 'model' is your fitted regression model and 'residuals' are the calculated residuals
fitted_values = model.fittedvalues

# Create a scatter plot with the fitted values from the model and the residuals
sns.residplot(x=fitted_values, y=residuals)

# Add label and title
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.title("Fitted Values v. Residuals");

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Access the fitted values from the model object fit earlier.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use `model.fittedvalues` to get the fitted values from a fit model called `model`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
#
# Call the `scatterplot()` function from the `seaborn` library and pass in the fitted values and residuals.
#
# Add a line to a figure using the `axline()` function.
#
# </details>

# %% [markdown]
# **Question:** Is the constant variance assumption met?

# %% [markdown]
# - The fitted values are in three distinct clusters because the categorical variable is dominating in this model, meaning that `TV` is the biggest factor that decides the `Sales`.
#
# - However, the variance where there are fitted values is randomly distributed, validating that the assumption is met.

# %% [markdown]
# ### Model assumption: No multicollinearity

# %% [markdown]
# The **no multicollinearity assumption** states that no two independent variables ($X_i$ and $X_j$) can be highly correlated with each other.
#
# Two common ways to check for multicollinearity are to:
#
# * Create scatterplots to show the relationship between pairs of independent variables
# * Use the variance inflation factor to detect multicollinearity
#
# Use one of these two methods to check your model's no multicollinearity assumption.

# %%
# Create a pairplot of the data.

sns.pairplot(data);

# %%
# Calculate the variance inflation factor (optional).

# Import variance_inflation_factor from statmodels
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a subset of data with continuous independent variables
X = data[['Radio', 'Social_Media']]

# Calculate the variance inflation factor for each variable
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Create a Dataframe with the VIF result for the column names in X

df_vif = pd.DataFrame(vif, index=X.columns, columns = ['VIF'])

# Display the VIF results.
df_vif
# Out:
#                    VIF
# Radio         5.170922
# Social_Media  5.170922

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Confirm that you previously created plots that could check the no multicollinearity assumption.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# The `pairplot()` function applied earlier to `data` plots the relationship between all continous variables  (e.g., between `Radio` and `Social Media`).
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# The `statsmodels` library has a function to calculate the variance inflation factor called `variance_inflation_factor()`.
#
# When using this function, subset the data to only include the continous independent variables (e.g., `Radio` and `Social Media`). Refer to external tutorials on how to apply the variance inflation factor function mentioned previously.
#
#
# </details>

# %% [markdown]
# **Question 8:** Is the no multicollinearity assumption met?
#
# - The preceding model only has one continous independent variable, meaning there are no multicollinearity issues.
#
# - VIF values for both `Radio` and `Social_Media` are approximately 5.17. A VIF value of 5.17 suggests that there is a moderate to high correlation between  these variables.
#
# - If our model used both `Radio` and `Social_Media` as predictors, there would be a moderate linear relationship between `Radio` and `Social_Media` that violates the multicollinearity assumption.

# %% [markdown]
# ## Step 4: Results and evaluation

# %% [markdown]
# ### Display the OLS regression results
#
# If the model assumptions are met, you can interpret the model results accurately.
#
# First, display the OLS regression results.

# %%
# Display the model results summary.

model_results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     1783.
# Date:                Sun, 23 Jul 2023   Prob (F-statistic):          1.63e-288
# Time:                        07:43:53   Log-Likelihood:                -2714.0
# No. Observations:                 572   AIC:                             5436.
# Df Residuals:                     568   BIC:                             5453.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         218.5261      6.261     34.902      0.000     206.228     230.824
# C(TV)[T.Low]     -154.2971      4.929    -31.303      0.000    -163.979    -144.616
# C(TV)[T.Medium]   -75.3120      3.624    -20.780      0.000     -82.431     -68.193
# Radio               2.9669      0.212     14.015      0.000       2.551       3.383
# ==============================================================================
# Omnibus:                       61.244   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.077
# Skew:                           0.046   Prob(JB):                     0.000119
# Kurtosis:                       2.134   Cond. No.                         142.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Question:** What is your interpretation of the model's R-squared?

# %% [markdown]
# Using `TV` and `Radio` as the independent variables results in a multiple linear regression model with $R^{2} = 0.904$. In other words, the model explains 90.4% of the variation in `Sales`. This makes the model an excellent predictor of `Sales`.

# %% [markdown]
# ### Interpret model coefficients

# %% [markdown]
# With the model fit evaluated, you can look at the coefficient estimates and the uncertainty of these estimates.
#
# Again, display the OLS regression results.

# %%
# Display the model results summary.

model_results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     1783.
# Date:                Sun, 23 Jul 2023   Prob (F-statistic):          1.63e-288
# Time:                        07:43:53   Log-Likelihood:                -2714.0
# No. Observations:                 572   AIC:                             5436.
# Df Residuals:                     568   BIC:                             5453.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         218.5261      6.261     34.902      0.000     206.228     230.824
# C(TV)[T.Low]     -154.2971      4.929    -31.303      0.000    -163.979    -144.616
# C(TV)[T.Medium]   -75.3120      3.624    -20.780      0.000     -82.431     -68.193
# Radio               2.9669      0.212     14.015      0.000       2.551       3.383
# ==============================================================================
# Omnibus:                       61.244   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.077
# Skew:                           0.046   Prob(JB):                     0.000119
# Kurtosis:                       2.134   Cond. No.                         142.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Question:** What are the model coefficients?

# %% [markdown]
# When `TV` and `Radio` are used to predict `Sales`, the model coefficients are:
#
# * $\beta_{0} =  218.5261$
# * $\beta_{TV-Low}= -154.2971$
# * $\beta_{TV-Medium} = -75.3120$
# * $\beta_{Radio} =  2.9669$
# * $\beta_{TV-High} = 0 $
#
# Since the coefficient for the 'High' category of the `TV` variable is not shown and interpreted as zero, it means that this category was chosen as the reference category (baseline) for the `TV` variable.

# %% [markdown]
# **Question:** How would you write the relationship between `Sales` and the independent variables as a linear equation?

# %% [markdown]
# $\text{Sales} = \beta_{0} + \beta_{1}*X_{1}+ \beta_{2}*X_{2}+ \beta_{3}*X_{3}$
#
# $\text{Sales} = \beta_{0} + \beta_{TV-Low}*X_{TV-Low}+ \beta_{TV-Medium}*X_{TV-Medium}+ \beta_{Radio}*X_{Radio}$
#
# $\text{Sales} = 218.5261 - 154.2971*X_{TV-Low} - 75.3120*X_{TV-Medium}+ 2.9669 *X_{Radio}$

# %% [markdown]
# **Question:** What is your intepretation of the coefficient estimates? Are the coefficients statistically significant?

# %% [markdown]
# **`TV` category interpretation:**
# - The default `TV` category for the model is `High` since there are coefficients for the other two `TV` categories, `Medium` and `Low`.
# - Because the coefficients for the `Medium` and `Low` in  `TV` categories are negative, that means the average of sales is lower for `Medium` or `Low` in `TV` categories compared to the `High` in `TV` category when `Radio` is at the same level.
# - For example, the model predicts that a `Low` `TV` promotion is 154.2971 lower on average compared to a `high` `TV` promotion given the same `Radio` promotion.
#
# **`Radio` Coefficient Interpretation:**
# - The coefficient for `Radio` is positive, confirming the positive linear relationship shown earlier during the exploratory data analysis.
# - With other variables held constant, for each \$1 million increase in the `Radio` budget, the `Sales` are expected to increase by \$2.9669 million.
#
# **Statistical Significance:**
# - The p-value for all coefficients is $0.000$, meaning all coefficients are statistically significant at significant level $\alpha=0.05$.
#
# **Confidence Intervals:**
# - The 95% confidence intervals for each coefficient should be reported when presenting results to stakeholders.
# - For example, there is a $95\%$ chance that the interval $[-163.979,-144.616]$ contains the true parameter of the slope of $\beta_{TVLow}$, which is the estimated difference in promotion sales when a `Low` `TV` promotion is chosen instead of a `High` `TV` promotion.

# %% [markdown]
# **Question:** Why is it important to interpret the beta coefficients?

# %% [markdown]
# $\beta$ coefficients allow you to estimate the magnitude and direction (positive or negative) of the effect of each *independent variable* on the *dependent variable*. The coefficient estimates can be converted to explainable insights, such as the connection between an increase in TV promotional budgets and sales mentioned previously.

# %% [markdown]
# **Question:** What are you interested in exploring based on your model?

# %% [markdown]
# - Additional plots to help convey the results, such as using the `seaborn regplot()` to plot the data with a best fit regression line
#
# - I want to split the dataset into training set and testing set to check the model. Then, I can present the result with stakeholders about the results about which kind of promotion the company should use to increase Sales but keep a decent budget.

# %% [markdown]
# **Question:** Do you think your model could be improved? Why or why not? How?

# %% [markdown]
# - **Granularity of TV Promotions:** Increasing the granularity of the `TV` promotions, such as considering more categories or the actual `TV` promotional budgets, can provide a more detailed and nuanced view of the relationship between `TV` spending and `Sales`. This additional granularity may capture more variability in the data and lead to a more accurate model.
#
# - **Additional Variables:** Incorporating additional relevant variables, such as the location of the marketing campaign or the time of year, can help capture other factors that may influence `Sales`. These variables might provide valuable context and contribute to a more comprehensive understanding of the factors impacting the outcome.
#
# - **Data Collection and Feature Engineering:** Gathering more detailed data and performing feature engineering to derive new variables can enhance the model's predictive power. For instance, creating interaction terms between certain variables or deriving new metrics might better represent complex relationships in the data.
#
# - **Model Validation and Testing:** Continuously validating and testing the model on new data or using different evaluation techniques can help assess its robustness and generalization ability. This process helps identify potential shortcomings and areas for improvement.
#
# - **Consider Nonlinear Relationships:** Exploring the possibility of nonlinear relationships between the independent and dependent variables may lead to improved model performance. This could involve using polynomial regression or other nonlinear regression techniques.
#
# - **Regularization Techniques:** As the model complexity increases with more variables, considering regularization techniques like Ridge or Lasso regression can help prevent overfitting and improve model stability.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **What are the key takeaways from this lab?**
#
# - Multiple linear regression is a powerful tool to estimate a dependent continous variable from several independent variables.
# - Exploratory data analysis is useful for selecting both numeric and categorical features for multiple linear regression.
# - Fitting multiple linear regression models may require trial and error to select variables that fit an accurate model while maintaining model assumptions.
#
# **What results can be presented from this lab?**
#
# Already answer above in Question: What is your intepretation of the coefficient estimates? Are the coefficients statistically significant?
#
# **How would you frame your findings to external stakeholders?**
#
# - 'High' `TV` promotional budgets have a substantial positive influence on `Sales`.
#
# - The model estimates that switching from a 'High' to 'Medium' `TV` promotional budget reduces sales by $\$75.3120$ million (95% CI $[-82.431,-68.193])$, and switching from a 'High' to 'Low' `TV` promotional budget reduces sales by $\$154.297$ million (95% CI $[-163.979,-144.616])$.
#
# - The model also estimates that an increase of $\$1$ million in the radio promotional budget will yield a $\$2.9669$ million increase in sales (95% CI $[2.551,3.383]$).
#
# - Thus, it is recommended that the business allot a 'High' promotional budget to `TV` when possible and invest in `Radio` promotions to increase sales.

# %% [markdown]
# #### **References**
#
# Saragih, H.S. (2020). [*Dummy Marketing and Sales Data*](https://www.kaggle.com/datasets/harrimansaragih/dummy-advertising-and-sales-data).

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
